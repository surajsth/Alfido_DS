# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data/loan_prediction.csv")
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
df.describe().T #trnspose
# df.describe()
# Out:
#                    count         mean          std    min     25%     50%  \
# ApplicantIncome    614.0  5403.459283  6109.041673  150.0  2877.5  3812.5
# CoapplicantIncome  614.0  1621.245798  2926.248369    0.0     0.0  1188.5
# LoanAmount         592.0   146.412162    85.587325    9.0   100.0   128.0
# Loan_Amount_Term   600.0   342.000000    65.120410   12.0   360.0   360.0
# Credit_History     564.0     0.842199     0.364878    0.0     1.0     1.0
#
#                        75%      max
# ApplicantIncome    5795.00  81000.0
# CoapplicantIncome  2297.25  41667.0
# LoanAmount          168.00    700.0
# Loan_Amount_Term    360.00    480.0
# Credit_History        1.00      1.0

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.fillna(method='ffill',inplace=True)
# Out:
# C:\Users\delll\AppData\Local\Temp\ipykernel_16572\4116506308.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill',inplace=True)

# %%
df.fillna(method='bfill',inplace=True)
# Out:
# C:\Users\delll\AppData\Local\Temp\ipykernel_16572\1626352436.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill',inplace=True)

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Gender',data=df,hue='Loan_Status',palette='Greens_d')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x='Loan_Status',data=df,palette='deep')
plt.show()
# Out:
# C:\Users\delll\AppData\Local\Temp\ipykernel_16572\2712754400.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Loan_Status',data=df,palette='deep')

# %%
plt.figure(figsize=(15,5))
sns.scatterplot(x="Loan_ID",y="LoanAmount",data=df)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df)
plt.show()

# %%
# Removing unwanted columns in the dataset
df.drop('Dependents',axis=1,inplace=True)
df.drop('ApplicantIncome',axis=1,inplace=True)
df.drop('CoapplicantIncome',axis=1,inplace=True)
df.drop('LoanAmount',axis=1,inplace=True)
df.drop('Loan_Amount_Term',axis=1,inplace=True)
df.drop('Credit_History',axis=1,inplace=True)
df.head()
# Out:
#     Loan_ID Gender Married     Education Self_Employed Property_Area  \
# 0  LP001002   Male      No      Graduate            No         Urban
# 1  LP001003   Male     Yes      Graduate            No         Rural
# 2  LP001005   Male     Yes      Graduate           Yes         Urban
# 3  LP001006   Male     Yes  Not Graduate            No         Urban
# 4  LP001008   Male      No      Graduate            No         Urban
#
#   Loan_Status
# 0           Y
# 1           N
# 2           Y
# 3           Y
# 4           Y

# %%
# Encoding using get_dummies OneHotEncoder
df1=pd.get_dummies(df,columns=["Gender","Married","Education","Self_Employed","Property_Area","Loan_Status"])
df1.head()
# Out:
#     Loan_ID  Gender_Female  Gender_Male  Married_No  Married_Yes  \
# 0  LP001002          False         True        True        False
# 1  LP001003          False         True       False         True
# 2  LP001005          False         True       False         True
# 3  LP001006          False         True       False         True
# 4  LP001008          False         True        True        False
#
#    Education_Graduate  Education_Not Graduate  Self_Employed_No  \
# 0                True                   False              True
# 1                True                   False              True
# 2                True                   False             False
# 3               False                    True              True
# 4                True                   False              True
#
#    Self_Employed_Yes  Property_Area_Rural  Property_Area_Semiurban  \
# 0              False                False                    False
# 1              False                 True                    False
# 2               True                False                    False
# 3              False                False                    False
# 4              False                False                    False
#
#    Property_Area_Urban  Loan_Status_N  Loan_Status_Y
# 0                 True          False           True
# 1                False           True          False
# 2                 True          False           True
# 3                 True          False           True
# 4                 True          False           True

# %%
df1.drop('Gender_Female',axis=1,inplace=True)
df1.drop('Married_No',axis=1,inplace=True)
df1.drop('Education_Graduate',axis=1,inplace=True)
df1.drop('Self_Employed_No',axis=1,inplace=True)
df1.drop('Property_Area_Rural',axis=1,inplace=True)
df1.drop('Loan_Status_N',axis=1,inplace=True)
df1.head()
# Out:
#     Loan_ID  Gender_Male  Married_Yes  Education_Not Graduate  \
# 0  LP001002         True        False                   False
# 1  LP001003         True         True                   False
# 2  LP001005         True         True                   False
# 3  LP001006         True         True                    True
# 4  LP001008         True        False                   False
#
#    Self_Employed_Yes  Property_Area_Semiurban  Property_Area_Urban  \
# 0              False                    False                 True
# 1              False                    False                False
# 2               True                    False                 True
# 3              False                    False                 True
# 4              False                    False                 True
#
#    Loan_Status_Y
# 0           True
# 1          False
# 2           True
# 3           True
# 4           True

# %%
X = df1[["Gender_Male","Married_Yes","Education_Not Graduate","Self_Employed_Yes","Property_Area_Semiurban","Property_Area_Urban"]].values
y=df1["Loan_Status_Y"].values

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(X,y,test_size=0.2,random_state=0)

from sklearn.linear_model import LogisticRegression 
m1=LogisticRegression()
m1.fit(xtrain,ytrain)
yp1=m1.predict(xtest)


from sklearn.tree import DecisionTreeClassifier
m2=DecisionTreeClassifier()
m2.fit(xtrain,ytrain)
yp2=m2.predict(xtest)

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
from sklearn.metrics import classification_report,confusion_matrix 
print("Logistic Regression :")
print(" accuracy is ",accuracy_score(ytest,yp1))
print(" precision score is ",precision_score(ytest,yp1))
print(" recall is ",recall_score(ytest,yp1))
print(" f1 score is ",f1_score(ytest,yp1))
print("                                                                                                              ")
print(" classification report is ",classification_report(ytest,yp1))
print(" confusion matrix is ",confusion_matrix(ytest,yp1))
# Out:
# Logistic Regression :
#  accuracy is  0.7154471544715447
#  precision score is  0.7310924369747899
#  recall is  0.9666666666666667
#  f1 score is  0.8325358851674641
#
#  classification report is                precision    recall  f1-score   support
#
#        False       0.25      0.03      0.05        33
#         True       0.73      0.97      0.83        90
#
#     accuracy                           0.72       123
#    macro avg       0.49      0.50      0.44       123
# weighted avg       0.60      0.72      0.62       123
#
#  confusion matrix is  [[ 1 32]
#  [ 3 87]]

# %%
print("Decision Tree Classifier :")
print(" accuracy is ",accuracy_score(ytest,yp2))
print(" precision score is ",precision_score(ytest,yp2))
print(" recall is ",recall_score(ytest,yp2))
print(" f1 score is ",f1_score(ytest,yp2))
print("                                                                                                              ")
print(" classification report is ",classification_report(ytest,yp2))
print(" confusion matrix is ",confusion_matrix(ytest,yp2))
# Out:
# Decision Tree Classifier :
#  accuracy is  0.7317073170731707
#  precision score is  0.7522123893805309
#  recall is  0.9444444444444444
#  f1 score is  0.8374384236453202
#
#  classification report is                precision    recall  f1-score   support
#
#        False       0.50      0.15      0.23        33
#         True       0.75      0.94      0.84        90
#
#     accuracy                           0.73       123
#    macro avg       0.63      0.55      0.53       123
# weighted avg       0.68      0.73      0.68       123
#
#  confusion matrix is  [[ 5 28]
#  [ 5 85]]

# %%
print("Logistic Regression :")
print(" accuracy is ",accuracy_score(ytest,yp1))
print(" precision score is ",precision_score(ytest,yp1))
print(" recall is ",recall_score(ytest,yp1))
print(" f1 score is ",f1_score(ytest,yp1))
print("***********************************************************************************************************")
print("Decision Tree Classifier :")
print(" accuracy is ",accuracy_score(ytest,yp2))
print(" precision score is ",precision_score(ytest,yp2))
print(" recall is ",recall_score(ytest,yp2))
print(" f1 score is ",f1_score(ytest,yp2))
# Out:
# Logistic Regression :
#  accuracy is  0.7154471544715447
#  precision score is  0.7310924369747899
#  recall is  0.9666666666666667
#  f1 score is  0.8325358851674641
# ***********************************************************************************************************
# Decision Tree Classifier :
#  accuracy is  0.7317073170731707
#  precision score is  0.7522123893805309
#  recall is  0.9444444444444444
#  f1 score is  0.8374384236453202

# %%
print("For Logistic Regression :")
print(" accuracy is ",accuracy_score(ytest,yp1))
print("For Decision tree :")
print(" accuracy is ",accuracy_score(ytest,yp2))
# Out:
# For Logistic Regression :
#  accuracy is  0.7154471544715447
# For Decision tree :
#  accuracy is  0.7317073170731707
